# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Banyuwangi = pd.read_csv("https://raw.githubusercontent.com/RafINMaulana/Capstone_Dataset/main/AnyConv.com__DATA_BANYUWANGI.csv")
Gresik = pd.read_csv("https://raw.githubusercontent.com/RafINMaulana/Capstone_Dataset/main/AnyConv.com__DATA_GRESIK.csv")
Sidoarjo = pd.read_csv("https://raw.githubusercontent.com/RafINMaulana/Capstone_Dataset/main/AnyConv.com__DATA_SIDOARJO.csv")
Surabaya = pd.read_csv("https://raw.githubusercontent.com/RafINMaulana/Capstone_Dataset/main/AnyConv.com__DATA_SURABAYA.csv")

# %%
Banyuwangi
# Out:
#         Tanggal  Tavg  RH_avg      RR    ss  ff_avg ddd_car
# 0    01-11-2023  28.4      74     NaN  10.5       2      S
# 1    02-11-2023  28.9      76     NaN   8.0       2      SW
# 2    03-11-2023  28.5      81     0.0  10.0       2      S
# 3    04-11-2023  28.3      78  8888.0   6.5       2      C
# 4    05-11-2023  28.6      75     0.0   9.0       1      C
# ..          ...   ...     ...     ...   ...     ...     ...
# 177  26-04-2024  28.7      83     2.8   2.0       2      NE
# 178  27-04-2024  28.9      82     0.0   7.2       2      SW
# 179  28-04-2024  28.7      84     NaN   8.2       3      S
# 180  29-04-2024  27.8      84     NaN   7.4       2      SW
# 181  30-04-2024  28.1      83  8888.0   6.5       1      C
#
# [182 rows x 7 columns]

# %%
Gresik
# Out:
#         Tanggal  Tavg  RH_avg   RR    ss  ff_avg ddd_car
# 0    01-11-2023  29.8      76  0.0  10.4       3      E
# 1    02-11-2023  30.3      77  0.0   7.9       2      E
# 2    03-11-2023  29.3      83  0.0  10.1       2      E
# 3    04-11-2023  29.9      78  4.9   9.1       3      E
# 4    05-11-2023  29.6      77  2.2  10.7       2      E
# ..          ...   ...     ...  ...   ...     ...     ...
# 177  26-04-2024  29.8      84  5.2   4.0       3      SE
# 178  27-04-2024  29.5      85  0.6   8.1       2      E
# 179  28-04-2024  30.3      82  7.1   0.0       3      SE
# 180  29-04-2024  30.2      80  2.4   9.1       3      SE
# 181  30-04-2024  29.7      82  1.7   8.7       3      E
#
# [182 rows x 7 columns]

# %%
Sidoarjo
# Out:
#         Tanggal  Tavg  RH_avg    RR    ss  ff_avg ddd_car
# 0    01-11-2023  30.6      70   0.0   9.8       2      C
# 1    02-11-2023  30.9      67   0.0   8.5       2      E
# 2    03-11-2023  30.6      74   NaN  10.3       2      C
# 3    04-11-2023  29.8      75   0.0   7.2       2      E
# 4    05-11-2023  30.4      76   0.8   4.6       2      E
# ..          ...   ...     ...   ...   ...     ...     ...
# 177  26-04-2024  29.6      82  11.3   0.0       3      E
# 178  27-04-2024  30.5      77   2.0   4.6       3      E
# 179  28-04-2024  30.2      78   NaN   8.7       3      E
# 180  29-04-2024  30.1      78   NaN   8.7       2      E
# 181  30-04-2024  30.0      75   NaN   6.5       3      E
#
# [182 rows x 7 columns]

# %%
Surabaya
# Out:
#         Tanggal  Tavg  RH_avg      RR   ss  ff_avg ddd_car
# 0    01-11-2023  31.3      64     0.0  9.1       2      SE
# 1    02-11-2023  31.5      63     0.0  8.2       3      SE
# 2    03-11-2023  30.7      69  8888.0  9.0       3      SE
# 3    04-11-2023  29.2      77     0.0  5.5       2      SE
# 4    05-11-2023  30.2      73    13.9  4.8       2      SE
# ..          ...   ...     ...     ...  ...     ...     ...
# 177  26-04-2024  29.8      80    10.3  0.0       2      SE
# 178  27-04-2024  30.9      75     0.0  6.3       4      SE
# 179  28-04-2024  31.1      73     0.0  8.4       3      SE
# 180  29-04-2024  30.6      75  8888.0  7.8       2      SE
# 181  30-04-2024  31.0      70     0.0  6.6       3      SE
#
# [182 rows x 7 columns]

# %% [markdown]
# ### Assessing Data

# %%
# Data Type
Banyuwangi.info()
Gresik.info()
Sidoarjo.info()
Surabaya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  182 non-null    object
#  1   Tavg     182 non-null    float64
#  2   RH_avg   182 non-null    int64
#  3   RR       134 non-null    float64
#  4   ss       178 non-null    float64
#  5   ff_avg   182 non-null    int64
#  6   ddd_car  182 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 10.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  182 non-null    object
#  1   Tavg     182 non-null    float64
#  2   RH_avg   182 non-null    int64
#  3   RR       174 non-null    float64
#  4   ss       182 non-null    float64
#  5   ff_avg   182 non-null    int64
#  6   ddd_car  182 non-null    object
# ...

# %%
# Menghapus Data
Banyuwangi = Banyuwangi.drop(columns = ['Tanggal', 'ss', 'ff_avg', 'ddd_car'])
Gresik = Gresik.drop(columns = ['Tanggal', 'ss', 'ff_avg', 'ddd_car'])
Sidoarjo = Sidoarjo.drop(columns = ['Tanggal', 'ss', 'ff_avg', 'ddd_car'])
Surabaya = Surabaya.drop(columns = ['Tanggal', 'ss', 'ff_avg', 'ddd_car'])

# %%
Banyuwangi
# Out:
#      Tavg  RH_avg      RR
# 0    28.4      74     NaN
# 1    28.9      76     NaN
# 2    28.5      81     0.0
# 3    28.3      78  8888.0
# 4    28.6      75     0.0
# ..    ...     ...     ...
# 177  28.7      83     2.8
# 178  28.9      82     0.0
# 179  28.7      84     NaN
# 180  27.8      84     NaN
# 181  28.1      83  8888.0
#
# [182 rows x 3 columns]

# %%
Gresik
# Out:
#      Tavg  RH_avg   RR
# 0    29.8      76  0.0
# 1    30.3      77  0.0
# 2    29.3      83  0.0
# 3    29.9      78  4.9
# 4    29.6      77  2.2
# ..    ...     ...  ...
# 177  29.8      84  5.2
# 178  29.5      85  0.6
# 179  30.3      82  7.1
# 180  30.2      80  2.4
# 181  29.7      82  1.7
#
# [182 rows x 3 columns]

# %%
Sidoarjo
# Out:
#      Tavg  RH_avg    RR
# 0    30.6      70   0.0
# 1    30.9      67   0.0
# 2    30.6      74   NaN
# 3    29.8      75   0.0
# 4    30.4      76   0.8
# ..    ...     ...   ...
# 177  29.6      82  11.3
# 178  30.5      77   2.0
# 179  30.2      78   NaN
# 180  30.1      78   NaN
# 181  30.0      75   NaN
#
# [182 rows x 3 columns]

# %%
Surabaya
# Out:
#      Tavg  RH_avg      RR
# 0    31.3      64     0.0
# 1    31.5      63     0.0
# 2    30.7      69  8888.0
# 3    29.2      77     0.0
# 4    30.2      73    13.9
# ..    ...     ...     ...
# 177  29.8      80    10.3
# 178  30.9      75     0.0
# 179  31.1      73     0.0
# 180  30.6      75  8888.0
# 181  31.0      70     0.0
#
# [182 rows x 3 columns]

# %%
Banyuwangi.isna().sum()
# Out:
# Tavg       0
# RH_avg     0
# RR        48
# dtype: int64

# %%
Gresik.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        8
# dtype: int64

# %%
Sidoarjo.isna().sum()
# Out:
# Tavg       0
# RH_avg     0
# RR        21
# dtype: int64

# %%
Surabaya.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        7
# dtype: int64

# %%
Banyuwangi = Banyuwangi.dropna(axis=0)
Banyuwangi.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        0
# dtype: int64

# %%
Gresik = Gresik.dropna(axis=0)
Gresik.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        0
# dtype: int64

# %%
Sidoarjo = Sidoarjo.dropna(axis=0)
Sidoarjo.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        0
# dtype: int64

# %%
Surabaya = Surabaya.dropna(axis=0)
Surabaya.isna().sum()
# Out:
# Tavg      0
# RH_avg    0
# RR        0
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Mengubah type data dteday pada kedua dataset menjadi datetime

# %%
Banyuwangi.describe()
# Out:
#              Tavg      RH_avg           RR
# count  134.000000  134.000000   134.000000
# mean    28.368657   77.940299  1067.494776
# std      0.833276    5.908782  2890.579942
# min     25.800000   58.000000     0.000000
# 25%     27.800000   74.000000     0.000000
# 50%     28.400000   78.000000     1.100000
# 75%     28.900000   82.000000    17.000000
# max     30.900000   90.000000  8888.000000

# %%
Gresik.describe()
# Out:
#              Tavg      RH_avg           RR
# count  174.000000  174.000000   174.000000
# mean    28.703448   84.390805   571.980460
# std      0.990702    4.409282  2166.637326
# min     26.200000   72.000000     0.000000
# 25%     28.100000   82.000000     0.000000
# 50%     28.900000   85.000000     2.550000
# 75%     29.400000   87.000000    15.575000
# max     31.100000   94.000000  8888.000000

# %%
Sidoarjo.describe()
# Out:
#              Tavg      RH_avg           RR
# count  161.000000  161.000000   161.000000
# mean    29.024845   80.310559   616.698758
# std      1.236226    6.481933  2246.939311
# min     25.900000   64.000000     0.000000
# 25%     28.100000   76.000000     0.000000
# 50%     29.000000   81.000000     1.700000
# 75%     30.000000   85.000000    18.300000
# max     31.500000   96.000000  8888.000000

# %%
Surabaya.describe()
# Out:
#              Tavg      RH_avg           RR
# count  175.000000  175.000000   175.000000
# mean    29.794286   75.594286  1224.693714
# std      1.094380    6.055393  3063.954006
# min     26.500000   60.000000     0.000000
# 25%     29.150000   73.000000     0.000000
# 50%     29.900000   76.000000     1.200000
# 75%     30.600000   79.000000    17.600000
# max     32.400000   93.000000  8888.000000
